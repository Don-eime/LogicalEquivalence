# %%
from equivalence_graph_search import *

# %%
not_of_p_or_not_q = Create.negation(Create.disjunction(p, not_q))

test_statement = Create.negation(not_p_or_not_q)
# G = EquivalenceGraphSearch(test_statement)
# G.to_svg('Tut 1-4-i.svg')

# %%
src = not_of_p_and_q
all_nodes, good_nodes, bad_nodes = explore_and_find_all_nodes_from(src)
# Out:
# ####
# searches_remaining = 20
# len(unsearched_nodes) = 1
# len(all_nodes) = 1
# ####
# searches_remaining = 19
# len(unsearched_nodes) = 2
# len(all_nodes) = 3
# ####
# searches_remaining = 18
# len(unsearched_nodes) = 1
# len(all_nodes) = 4

# %%
print(p_and_q.truth_table)
# Out:
#        p      q  result_value
# 0  False  False         False
# 1   True  False         False
# 2  False   True         False
# 3   True   True          True

# %%
p_and_q.truth_table == q_and_p.truth_table
# Out:
#       p     q  result_value
# 0  True  True          True
# 1  True  True          True
# 2  True  True          True
# 3  True  True          True

# %%
from pprint import pprint
pprint('p and q:')
pprint(p_and_q.truth_table)
print()
pprint(q_and_p.truth_table)
# Out:
# 'p and q:'
#        p      q  result_value
# 0  False  False         False
# 1   True  False         False
# 2  False   True         False
# 3   True   True          True
#
#        p      q  result_value
# 0  False  False         False
# 1   True  False         False
# 2  False   True         False
# 3   True   True          True

# %%
p_and_q.truth_table == q_and_p.truth_table
# Out:
#       p     q  result_value
# 0  True  True          True
# 1  True  True          True
# 2  True  True          True
# 3  True  True          True

# %%
bad_nodes
# Out:
# []

# %%
[type(n) for n in all_nodes]
# Out:
# [equivalence_graph_search.Node,
#  equivalence_graph_search.Node,
#  equivalence_graph_search.Node,
#  equivalence_graph_search.Node]

# %%
[n.statement.truth_table == src.truth_table for n in all_nodes]
# Out:
# [      p     q  result_value
#  0  True  True          True
#  1  True  True          True
#  2  True  True          True
#  3  True  True          True,
#        p     q  result_value
#  0  True  True          True
#  1  True  True          True
#  2  True  True          True
#  3  True  True          True,
#        p     q  result_value
#  0  True  True          True
#  1  True  True          True
#  2  True  True          True
#  3  True  True          True,
#        p     q  result_value
#  0  True  True          True
#  1  True  True          True
#  2  True  True          True
#  3  True  True          True]

# %%
good_nodes
# Out:
# []

# %%
all, good, bad = explore_and_find_all_nodes_from(test_statement)
set([n.statement.truth_table == test_statement.truth_table for n in all])
# Out:
# ####
# searches_remaining = 20
# len(unsearched_nodes) = 1
# len(all_nodes) = 1
# ####
# searches_remaining = 19
# len(unsearched_nodes) = 3
# len(all_nodes) = 4
# ####
# searches_remaining = 18
# len(unsearched_nodes) = 5
# len(all_nodes) = 9
# ####
# searches_remaining = 17
# len(unsearched_nodes) = 3
# len(all_nodes) = 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-a29fffefbdec> in <module>
#       1 all, good, bad = explore_and_find_all_nodes_from(test_statement)
# ----> 2 set([n.statement.truth_table == test_statement.truth_table for n in all])
#       3
#
# c:\users\dteei\onedrive\projects\logicalequivalence\venv\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1783
#    1784     def __hash__(self) -> int:
# -> 1785         raise TypeError(
#    1786             f"{repr(type(self).__name__)} objects are mutable, "
#    1787             f"thus they cannot be hashed"
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed

# %%
complex_statement = Create.conjunction(test_statement, not_p_and_not_q)
all, good, bad = explore_and_find_all_nodes_from(complex_statement)

# %% [markdown]
# Just testing the NegationLaw quickly.

# %%
not_q_AND_not_not_q = Create.conjunction(not_q, Create.negation(not_q))
log_eq.NegationLaw.eligible(not_q_AND_not_not_q)

ins = not_q_AND_not_not_q
outs = log_eq.NegationLaw.apply(ins)

# %%
ins.truth_table

# %%
outs.truth_table

# %% [markdown]
# What are the differences between law eligibilities of law pairs that are connected
# by commutability?

# %%
# Getting a list of all pairs linked by commutability
commut_edges = []
for node in all:
    for edge in node.get_edges:
        if edge.law == log_eq.CommutativeLaw:
            commut_edges.append(edge)

# %%
e = commut_edges[0]

# %%
n1_laws = [ej.law for ej in e.n1.get_edges]
n2_laws = [ej.law for ej in e.n2.get_edges]

# %%
pprint(n1_laws)
print('####')
pprint(n2_laws)
# Out:
# [<class 'logical_equivalence.DeMorgansLaw'>,
#  <class 'logical_equivalence.CommutativeLaw'>,
#  <class 'logical_equivalence.ReverseDeMorgansLaw'>]
# ####
# [<class 'logical_equivalence.DeMorgansLaw'>,
#  <class 'logical_equivalence.CommutativeLaw'>,
#  <class 'logical_equivalence.ReverseDeMorgansLaw'>]

# %% [markdown]
# so i can get the list of edge laws of both nodes of an edge.
#
# No i need to automate looking for unqiue edge laws
# so cutting out reverses and the like

# %%
n1_unique_laws = [law for law in n1_laws if law.short_name not in [law.short_name for law in n2_laws]]

pprint(n1_unique_laws)
# Out:
# []

# %%
def unique_edges_from_edge(e: Edge):
    """ Law names are same for forward and reverse laws"""
    n1_laws = [ej.law for ej in e.n1.get_edges]
    n2_laws = [ej.law for ej in e.n2.get_edges]

    n1_unique_laws = [law for law in n1_laws if law.short_name not in [law.short_name for law in n2_laws]]
    n2_unique_laws = [law for law in n2_laws if law.short_name not in [law.short_name for law in n1_laws]]

    return n1_unique_laws, n2_unique_laws

# %%
def zip_edge_with_eligibilities_of_n1_and_n2(edge_list):
    return list(zip(edge_list, map(unique_edges_from_edge, edge_list)))

# %%
[(e, un[0], un[1]) for e, un in unique_edge_pairs if un[0] or un[1]]
# Out:
# []

# %%
def edges_that_provide_new_options(edge_list):
    edge_elig_zip = zip_edge_with_eligibilities_of_n1_and_n2(edge_list)
    only_edges_with_unique_laws_on_atleast_one_side = [(e, un[0], un[1]) for e, un in edge_elig_zip if un[0] or un[1]]
    return only_edges_with_unique_laws_on_atleast_one_side

# %%
def all_edges_from(node_list):
    edges = []
    for node in node_list:
        edges.extend(node.get_edges)
    return edges

# %%
all_edges = all_edges_from(all)

# %%
new_option_edges = edges_that_provide_new_options(all_edges)
print(f'{len(all_edges)=}, {len(new_option_edges)=}')
# Out:
# len(all_edges)=28, len(new_option_edges)=18

# %%
pprint(new_option_edges, indent=2, depth=4)
# Out:
# [ ( <equivalence_graph_search.Edge object at 0x0000024E22005E50>,
#     [<class 'logical_equivalence.DeMorgansLaw'>],
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DoubleNegativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F97430>,
#     [ <class 'logical_equivalence.CommutativeLaw'>,
#       <class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     [<class 'logical_equivalence.DoubleNegativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F97DC0>,
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DoubleNegativeLaw'>],
#     [<class 'logical_equivalence.DeMorgansLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F97FD0>,
#     [<class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F977F0>,
#     [<class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F97C10>,
#     [<class 'logical_equivalence.DeMorgansLaw'>],
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DoubleNegativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21E33A60>,
#     [ <class 'logical_equivalence.CommutativeLaw'>,
#       <class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     [<class 'logical_equivalence.DoubleNegativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FCF910>,
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DeMorgansLaw'>],
#     [<class 'logical_equivalence.CommutativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21ED1E80>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     [ <class 'logical_equivalence.CommutativeLaw'>,
#       <class 'logical_equivalence.ReverseDeMorgansLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21F8AC10>,
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DoubleNegativeLaw'>],
#     [<class 'logical_equivalence.DeMorgansLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FE2790>,
#     [<class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E220088E0>,
#     [<class 'logical_equivalence.ReverseDeMorgansLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E220032E0>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E22003F40>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FD59D0>,
#     [ <class 'logical_equivalence.DoubleNegativeLaw'>,
#       <class 'logical_equivalence.DeMorgansLaw'>],
#     [<class 'logical_equivalence.CommutativeLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FD5400>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     [ <class 'logical_equivalence.CommutativeLaw'>,
#       <class 'logical_equivalence.ReverseDeMorgansLaw'>]),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FDD730>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     []),
#   ( <equivalence_graph_search.Edge object at 0x0000024E21FDD3A0>,
#     [<class 'logical_equivalence.DoubleNegativeLaw'>],
#     [])]
